# %% [markdown]
# <a href="https://colab.research.google.com/github/kithulovali/instacart-eda/blob/main/instacart_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/yasserh/instacart-online-grocery-basket-analysis-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: goffartjeanmarc
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/yasserh/instacart-online-grocery-basket-analysis-dataset
# ...
# 100%|██████████| 197M/197M [00:00<00:00, 694MB/s]

# %%
pip install numpy  pandas  matplotlib

# %%
# dependencies imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##loading datasets

# %%
df_order_products__prior = pd.read_csv("/content/instacart-online-grocery-basket-analysis-dataset/order_products__prior.csv")
df_orders = pd.read_csv("/content/instacart-online-grocery-basket-analysis-dataset/orders.csv")
df_products = pd.read_csv("/content/instacart-online-grocery-basket-analysis-dataset/products.csv")

# %% [markdown]
# ## about  datasets

# %%
print(df_order_products__prior.info())
print(df_orders.info())
print(df_products.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49688 entries, 0 to 49687
# ...

# %%
df_orders.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
df_orders.isna().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %% [markdown]
# ## merging datasets

# %%
df_orders_prior_merged = df_orders.merge(df_order_products__prior)
#df_orders_products_priors = df_order_products.merge()
print(df_orders_prior_merged.info())
print(df_orders_prior_merged.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 2.4+ GB
# None
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0

# %% [markdown]
# ## checking for Null cells and duplicated values to be cleaned

# %%
print(df_orders_prior_merged.isna().sum())
print(df_orders_prior_merged.duplicated())
# Out:
# order_id                        0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# dtype: int64
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 32434484    False
# 32434485    False
# 32434486    False
# 32434487    False
# 32434488    False
# Length: 32434489, dtype: bool
