# %% [markdown]
# <a href="https://colab.research.google.com/github/kithulovali/instacart-eda/blob/main/notebooks/instacart-eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/yasserh/instacart-online-grocery-basket-analysis-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: goffartjeanmarc
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/yasserh/instacart-online-grocery-basket-analysis-dataset
# ...
# 100%|██████████| 197M/197M [00:00<00:00, 778MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### datasets loading

# %%
orders = pd.read_csv("/content/instacart-online-grocery-basket-analysis-dataset/orders.csv")
products = pd.read_csv("/content/instacart-online-grocery-basket-analysis-dataset/products.csv")
order_products__prior = pd.read_csv("/content/instacart-online-grocery-basket-analysis-dataset/order_products__prior.csv")

# %% [markdown]
# ### datasets understanding
